# %%
import tensorflow as tf
from data_loader.data_load import Dataset

# Load configuration file
config = open('/workspaces/DD2424-project/configs/alexnet_modded_config.json')

#Create Dataset of tiny-imagenet from config
dataset = Dataset(config)

#Get training data and validation data
ds_train = dataset.get_data('train')
ds_test = dataset.get_data('val')
# Out:
# 1 Physical GPUs, 1 Logical GPUs
# WARNING:tensorflow:AutoGraph could not transform <bound method Dataset.__parse_data of <data_loader.data_load.Dataset object at 0x7f3f66d64710>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: Mangled names are not yet supported by AutoGraph
# WARNING: AutoGraph could not transform <bound method Dataset.__parse_data of <data_loader.data_load.Dataset object at 0x7f3f66d64710>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: Mangled names are not yet supported by AutoGraph

# %%
#Show a subset of training data 
dataset.show_batch(dataset='train')

# %%
#Show a subset of validation data 
dataset.show_batch(dataset='val')

# %%
# %load_ext tensorboard

# %%
# %tensorboard --logdir=logs --host=0.0.0.0 --port=6060

# %%
from models.alexnet_modded_filter import AlexNetModded

config_alex = open('/workspaces/DD2424-project/configs/alexnet_modded_config.json')

#Train modded alexnet according to configuration file
alex_modded = AlexNetModded(config_alex)

alex_modded.set_train_data(ds_train)
alex_modded.set_test_data(ds_test)

alex_modded.generate_model()
alex_modded.summary()
alex_modded.start_train()
alex_modded.evaluate()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d (Conv2D)              (None, 62, 62, 32)        896
# _________________________________________________________________
# layer_normalization (LayerNo (None, 62, 62, 32)        64
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 30, 30, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 30, 30, 32)        25632
# _________________________________________________________________
# layer_normalization_1 (Layer (None, 30, 30, 32)        64
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 14, 14, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 14, 14, 64)        18496
# ...
